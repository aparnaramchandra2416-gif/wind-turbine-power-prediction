# %% [markdown]
# <a href="https://colab.research.google.com/github/aparnaramchandra2416-gif/wind-turbine-power-prediction/blob/main/Wind_turbine_power_output_prediction_from_wind_speed_and_blade_length.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Wind turbine power output prediction from wind speed and blade length**

# %% [markdown]
# NAME:APARNA R
#
# BRANCH: CSE(DS)
#
# EMAIL: aparnaramchandra2416@gmail.com
#
# COLLEGE EMAIL: aparna.24ds@cambridge.edu.in

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **IMPORTING THE DATA SETS**

# %%
df = pd.read_csv('/content/wind_power.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   wind_speed_ms               961 non-null    float64
#  1   blade_length_m              939 non-null    float64
#  2   turbine_age_years           953 non-null    float64
#  3   hub_height_m                949 non-null    float64
#  4   turbine_type                953 non-null    object
#  5   rated_power_kw              949 non-null    float64
#  6   cut_in_speed_ms             954 non-null    float64
#  7   cut_out_speed_ms            949 non-null    float64
#  8   air_density_kgm3            956 non-null    float64
#  9   turbulence_intensity        948 non-null    float64
#  10  maintenance_status          947 non-null    object
#  11  terrain_type                946 non-null    object
#  12  wind_direction_variability  952 non-null    object
# ...

# %% [markdown]
# **TO CHECK HOW MANY VALUES ARE MISSING IN EACH DATA**

# %%
df.isnull().sum()
# Out:
# wind_speed_ms                 39
# blade_length_m                61
# turbine_age_years             47
# hub_height_m                  51
# turbine_type                  47
# rated_power_kw                51
# cut_in_speed_ms               46
# cut_out_speed_ms              51
# air_density_kgm3              44
# turbulence_intensity          52
# maintenance_status            53
# terrain_type                  54
# wind_direction_variability    48
# power_output_kw               40
# dtype: int64

# %%
df['wind_speed_ms'].isna().sum()
# Out:
# np.int64(39)

# %% [markdown]
# **39 VALUES MISSING. REPLACE USING MEDIAN**

# %%
df['wind_speed_ms'].fillna(df['wind_speed_ms'].median(),
                         inplace=True)

# %% [markdown]
# **61 VALUES MISSING.REPLACE USING MEAN.**

# %%
df['blade_length_m'].fillna(df['blade_length_m'].mean(),
                         inplace=True)
# Out:
# /tmp/ipython-input-235868110.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['blade_length_m'].fillna(df['blade_length_m'].mean(),

# %% [markdown]
# **47 VALUES ARE MISSING.REPLACE USING MEDIAN.**

# %%
df['turbine_age_years'].fillna(df['turbine_age_years'].median(),
                         inplace=True)
# Out:
# /tmp/ipython-input-2681147222.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['turbine_age_years'].fillna(df['turbine_age_years'].median(),

# %% [markdown]
# **51 VALUES ARE MISSING.REPLACE USING MEAN.**

# %%
df['hub_height_m'].fillna(df['hub_height_m'].mean(),
                         inplace=True)
# Out:
# /tmp/ipython-input-3660210151.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['hub_height_m'].fillna(df['hub_height_m'].mean(),

# %% [markdown]
# **47 VALUES ARE MISSING.**

# %%
df['turbine_type'].fillna(df['turbine_type']=='Not Available',
                  inplace=True)
# Out:
# /tmp/ipython-input-3106205254.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['turbine_type'].fillna(df['turbine_type']=='Not Available',

# %% [markdown]
# **51 VALUES ARE MISSING. REPLACE THEM USING MEDIAN**

# %%
df['rated_power_kw'].fillna(df['rated_power_kw'].median(),
                         inplace=True)
# Out:
# /tmp/ipython-input-3846836251.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['rated_power_kw'].fillna(df['rated_power_kw'].median(),

# %% [markdown]
# **46 VALUES ARE MISSING.REPLACE THEM USING MEAN.**

# %%
df['cut_in_speed_ms'].fillna(df['cut_in_speed_ms'].mean(),
                         inplace=True)
# Out:
# /tmp/ipython-input-2888564867.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['cut_in_speed_ms'].fillna(df['cut_in_speed_ms'].mean(),

# %% [markdown]
# **51 VALUES ARE MISSING.REPLACE THEM USING MEAN.**

# %%
df['cut_out_speed_ms'].fillna(df['cut_out_speed_ms'].mean(),
                         inplace=True)
# Out:
# /tmp/ipython-input-3828553477.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['cut_out_speed_ms'].fillna(df['cut_out_speed_ms'].mean(),

# %% [markdown]
# **44 VALUES ARE MISSING.REPLACE THEM USING MEAN.**

# %%
df['air_density_kgm3'].fillna(df['air_density_kgm3'].mean(),
                         inplace=True)
# Out:
# /tmp/ipython-input-2307542740.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['air_density_kgm3'].fillna(df['air_density_kgm3'].mean(),

# %% [markdown]
# **52 VALUES ARE MISSING. REPLACE THEM USING MEDIAN.**

# %%
df['turbulence_intensity'].fillna(df['turbulence_intensity'].median(),
                         inplace=True)
# Out:
# /tmp/ipython-input-802316060.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['turbulence_intensity'].fillna(df['turbulence_intensity'].median(),

# %% [markdown]
# **53 VALUES ARE MISSING.**

# %%
df['maintenance_status'].fillna(df['maintenance_status']=='Not Available',
                  inplace=True)
# Out:
# /tmp/ipython-input-3631033679.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['maintenance_status'].fillna(df['maintenance_status']=='Not Available',

# %% [markdown]
# **54 VALUES ARE MISSING.**

# %%
df['terrain_type'].fillna(df['terrain_type']=='Not Available',
                  inplace=True)
# Out:
# /tmp/ipython-input-867247971.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['terrain_type'].fillna(df['terrain_type']=='Not Available',

# %% [markdown]
# **48 VALUES ARE MISSING.**

# %%
df['wind_direction_variability'].fillna(df['wind_direction_variability']=='Not Available',
                  inplace=True)
# Out:
# /tmp/ipython-input-119617065.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['wind_direction_variability'].fillna(df['wind_direction_variability']=='Not Available',

# %% [markdown]
# **40 VALUES ARE MISSING.**

# %%
df['power_output_kw'].fillna(df['power_output_kw'].median(),
                         inplace=True)
# Out:
# /tmp/ipython-input-3170676716.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['power_output_kw'].fillna(df['power_output_kw'].median(),

# %%
df=pd.get_dummies(df)

# %%
df
# Out:
#      wind_speed_ms  blade_length_m  turbine_age_years  hub_height_m  \
# 0         5.104369       47.091836           8.830999     70.339044
# 1        17.666834       44.622260           0.501787     96.460496
# 2        12.157650       31.458768          14.175217    100.280458
# 3         8.910482       48.563840           6.885122    108.069957
# 4        19.360413       40.550983          16.540931    120.246598
# ..             ...             ...                ...           ...
# 995      19.163794       45.504968          11.964236    108.990249
# 996      22.463101       72.581589           9.396057    145.418826
# 997      23.709262       22.711691           3.231120    118.559592
# 998      12.603231       75.598356           2.735335    113.195802
# 999      13.193160       36.257997           1.736524     67.163335
#
#      rated_power_kw  cut_in_speed_ms  cut_out_speed_ms  air_density_kgm3  \
# 0            3000.0         3.162759         23.060822          1.219210
# ...

# %%
X = df.drop('power_output_kw', axis=1)

Y = df['power_output_kw']

# %%
X
# Out:
#      wind_speed_ms  blade_length_m  turbine_age_years  hub_height_m  \
# 0         5.104369       47.091836           8.830999     70.339044
# 1        17.666834       44.622260           0.501787     96.460496
# 2        12.157650       31.458768          14.175217    100.280458
# 3         8.910482       48.563840           6.885122    108.069957
# 4        19.360413       40.550983          16.540931    120.246598
# ..             ...             ...                ...           ...
# 995      19.163794       45.504968          11.964236    108.990249
# 996      22.463101       72.581589           9.396057    145.418826
# 997      23.709262       22.711691           3.231120    118.559592
# 998      12.603231       75.598356           2.735335    113.195802
# 999      13.193160       36.257997           1.736524     67.163335
#
#      rated_power_kw  cut_in_speed_ms  cut_out_speed_ms  air_density_kgm3  \
# 0            3000.0         3.162759         23.060822          1.219210
# ...

# %%
Y
# Out:
# 0      2792.360710
# 1      6175.704023
# 2      7745.335181
# 3      1358.078129
# 4      7432.914789
#           ...
# 995    1542.099558
# 996    4963.185761
# 997    5285.869983
# 998    6206.724330
# 999    1892.029153
# Name: power_output_kw, Length: 1000, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,
                                                    Y,
                                                    train_size=0.8,
                                                    test_size=0.2,
                                                    random_state=42)

# %% [markdown]
# **BUILD REGREESION MODEL**

# %%
regression_model = LinearRegression()

# %%
regression_model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
regression_model.predict(X_test)
# Out:
# array([3542.16435406, 4492.02919999, 3865.94208626, 3260.56706507,
#        4110.95807391, 3995.11283465, 4093.9580075 , 3464.72386523,
#        3581.58877969, 4284.32970535, 3466.20740174, 4829.28766328,
#        3178.45786692, 3936.83111593, 3822.05572737, 3951.97729559,
#        3803.60538799, 4534.32637353, 3797.32239433, 3492.03522656,
#        3874.29923932, 3623.08685693, 4029.95254517, 3884.84545504,
#        3738.74519725, 4171.32994911, 3849.63874859, 3860.6801565 ,
#        4091.48514485, 3632.71944757, 4072.85732437, 3332.67090713,
#        3564.07586508, 3080.77101257, 4224.73720635, 3757.10419409,
#        4134.18054817, 3743.37873302, 3394.91312219, 3690.55533063,
#        4155.89893157, 4017.05312829, 3636.92456768, 3377.42677333,
#        3547.78066622, 4294.95947254, 4352.43691795, 3600.28321036,
#        3470.7360772 , 3505.71407804, 3201.12756942, 3651.80897118,
#        4172.34070888, 3278.34646331, 3328.14218217, 3873.25946967,
# ...

# %%
Y_pred = regression_model.predict(X_test)

# %%
regression_model.coef_
# Out:
# array([ 1.30844845e+01, -2.42681534e+00,  1.50058838e+01, -3.81147187e+00,
#        -6.05391137e-02,  2.30216054e+02,  4.11666655e+00,  1.60290427e+03,
#         1.76511949e+03, -2.08655447e+02,  1.49841063e+02,  5.88143840e+01,
#        -1.64975451e+01, -2.26917308e+02, -4.50383959e+01,  3.38482648e+02,
#        -5.00293990e+01,  1.85363131e+02, -2.70701003e+02,  1.49328492e+02,
#        -1.23072684e+02,  5.90820648e+01, -1.11483676e+02, -3.29683161e+01,
#         1.63568919e+02, -1.91169267e+01])

# %%
regression_model.intercept_
# Out:
# np.float64(1239.7550291835223)

# %%
r2_score(Y_test, Y_pred)
# Out:
# -0.05506687233884233

# %%
mean_squared_error(Y_test, Y_pred)
# Out:
# 5672079.8343114015

# %%
RMSE = np.sqrt(mean_squared_error(Y_test, Y_pred))

print(RMSE)
# Out:
# 2381.612864071615

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from typing import Annotated
sns.countplot(x='power_output_kw', data=df)
plt.show()

# %% [markdown]
# **Histogram – Wind Speed**

# %%
plt.figure(figsize=(6,4))
plt.hist(df['wind_speed_ms'], bins=20)
plt.xlabel("Wind Speed (m/s)")
plt.ylabel("Frequency")
plt.title("Histogram of Wind Speed")
plt.show()

# %% [markdown]
# **Histogram – Blade Length**

# %%
plt.figure(figsize=(6,4))
plt.hist(df['blade_length_m'], bins=20)
plt.xlabel("Blade Length (m)")
plt.ylabel("Frequency")
plt.title("Histogram of Blade Length")
plt.show()

# %% [markdown]
# **Histogram – Power Output**

# %%
plt.figure(figsize=(6,4))
plt.hist(df['power_output_kw'], bins=20)
plt.xlabel("Power Output (kW)")
plt.ylabel("Frequency")
plt.title("Histogram of Power Output")
plt.show()

# %%
df[['wind_speed_ms','blade_length_m','power_output_kw']].hist(bins=20, figsize=(10,6))
plt.suptitle("Histograms of Wind Speed, Blade Length and Power Output")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
categorical_cols = df.select_dtypes(include='object').columns

for col in categorical_cols:
    plt.figure(figsize=(6,4))
    sns.countplot(x=df[col])
    plt.title(f"Count Plot of {col}")
    plt.xticks(rotation=45)
    plt.show()

# %%
numerical_cols = df.select_dtypes(include='number').columns

for col in numerical_cols:
    plt.figure(figsize=(6,4))
    binned_data = pd.cut(df[col], bins=5)   # divide into 5 ranges
    sns.countplot(x=binned_data)
    plt.title(f"Count Plot of {col}")
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# **Scatter Plot – Wind Speed vs Power Output**

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.scatter(df['wind_speed_ms'], df['power_output_kw'])
plt.xlabel("Wind Speed (m/s)")
plt.ylabel("Power Output (kW)")
plt.title("Wind Speed vs Power Output")
plt.grid(True)
plt.show()

# %% [markdown]
# **Blade Length vs Power Output**

# %%
plt.figure(figsize=(6,4))
plt.scatter(df['blade_length_m'], df['power_output_kw'])
plt.xlabel("Blade Length (m)")
plt.ylabel("Power Output (kW)")
plt.title("Blade Length vs Power Output")
plt.grid(True)
plt.show()

# %% [markdown]
# **boxplot**

# %%
plt.figure(figsize=(7,4))
df[['wind_speed_ms','blade_length_m','power_output_kw',]].boxplot()
plt.title("Boxplot of Wind Speed, Blade Length & Power Output")
plt.show()

# %% [markdown]
# **PREDICTION V/S ACTUAL DATA**

# %%
sns.scatterplot(x=Y_test, y=Y_pred)
plt.plot(Y_test, Y_test, color='red')
plt.show()
